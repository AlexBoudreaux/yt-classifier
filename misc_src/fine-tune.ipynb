# %%
import openai
import os
openai.api_key = "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"

openai.File.create(
  file=open("new-training-data.jsonl", "r"),
  purpose='fine-tune'
)
# Out:
# <File file id=file-uxAmqRxjUQAZuumJw2zd3vYZ at 0x11b19bdd0> JSON: {
#   "object": "file",
#   "id": "file-uxAmqRxjUQAZuumJw2zd3vYZ",
#   "purpose": "fine-tune",
#   "filename": "file",
#   "bytes": 423425,
#   "created_at": 1693428985,
#   "status": "uploaded",
#   "status_details": null
# }

# %%
openai.File.list()
# Out:
# <OpenAIObject list at 0x117eb30b0> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "object": "file",
#       "id": "file-ttiSuWPJS6fgfG3DnCkwirIU",
#       "purpose": "fine-tune",
#       "filename": "file",
#       "bytes": 423425,
#       "created_at": 1693426843,
#       "status": "uploaded",
#       "status_details": null
#     },
#     {
#       "object": "file",
#       "id": "file-C62X3tmZCgQZNfCMUKhGwvIZ",
#       "purpose": "fine-tune",
#       "filename": "training-data.jsonl",
#       "bytes": 326865,
#       "created_at": 1691870831,
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "object": "file",
#       "id": "file-IsDPKPNEa0v3yiajMIoBBJt1",
#       "purpose": "fine-tune",
#       "filename": "training-data.jsonl",
#       "bytes": 326865,
#       "created_at": 1691850619,
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "object": "file",
# ...

# %%
openai.FineTuningJob.create(training_file="file-uxAmqRxjUQAZuumJw2zd3vYZ", model="gpt-3.5-turbo")
# Out:
# <FineTuningJob fine_tuning.job id=ftjob-d817UVuSCVKQyjC7XRB0vBe3 at 0x11b1312b0> JSON: {
#   "object": "fine_tuning.job",
#   "id": "ftjob-d817UVuSCVKQyjC7XRB0vBe3",
#   "model": "gpt-3.5-turbo-0613",
#   "created_at": 1693429119,
#   "finished_at": null,
#   "fine_tuned_model": null,
#   "organization_id": "org-T6bYvYJr8ulggtQqe0MnmbmL",
#   "result_files": [],
#   "status": "created",
#   "validation_file": null,
#   "training_file": "file-uxAmqRxjUQAZuumJw2zd3vYZ",
#   "hyperparameters": {
#     "n_epochs": 3
#   },
#   "trained_tokens": null
# }

# %%
openai.FineTuningJob.retrieve('ftjob-d817UVuSCVKQyjC7XRB0vBe3')
# Out:
# <FineTuningJob fine_tuning.job id=ftjob-d817UVuSCVKQyjC7XRB0vBe3 at 0x11b15b4d0> JSON: {
#   "object": "fine_tuning.job",
#   "id": "ftjob-d817UVuSCVKQyjC7XRB0vBe3",
#   "model": "gpt-3.5-turbo-0613",
#   "created_at": 1693429119,
#   "finished_at": 1693430178,
#   "fine_tuned_model": "ft:gpt-3.5-turbo-0613:personal::7tMpsDay",
#   "organization_id": "org-T6bYvYJr8ulggtQqe0MnmbmL",
#   "result_files": [
#     "file-bllWKRCrC073cK9J4JZoZQ8n"
#   ],
#   "status": "succeeded",
#   "validation_file": null,
#   "training_file": "file-uxAmqRxjUQAZuumJw2zd3vYZ",
#   "hyperparameters": {
#     "n_epochs": 3
#   },
#   "trained_tokens": 302406
# }
